# %%
import akshare as ak
import json

df = ak.stock_zh_a_hist(symbol="603019", period="daily", start_date="20260108", end_date="20260108", adjust="")
price = df.at[0, "收盘"]
print(price)
print(stock_zh_a_hist_df.to_json())
# Out:
# 93.0

# %%
df = ak.spot_symbol_table_sge()
print(df)
# Out:
#     序号        品种
# 0    1   Au99.99
# 1    2   Au99.95
# 2    3    Au100g
# 3    4   Pt99.95
# 4    5   Ag(T+D)
# 5    6   Au(T+D)
# 6    7  mAu(T+D)
# 7    8  Au(T+N1)
# 8    9  Au(T+N2)
# 9   10   Ag99.99
# 10  11  iAu99.99
# 11  12    Au99.5
# 12  13   iAu100g
# 13  14   iAu99.5
# 14  15    PGC30g
# 15  16  NYAuTN06
# 16  17  NYAuTN12

# %%
# df = ak.spot_hist_sge(symbol='Au99.99')
df = ak.spot_quotations_sge(symbol="Au99.99")
print(df.shape)
print(df.at[df.index[-1], "现价"])
# Out:
# (698, 4)
# 999.49
